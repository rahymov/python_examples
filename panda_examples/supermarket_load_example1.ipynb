# %%
import os
os.listdir()
# Out:
# ['supermarket_load_example1.py.ipynb',
#  '.DS_Store',
#  'pandas_example_1.py.ipynb',
#  'Readme.md',
#  'pandas_web_scaping_1.py.ipynb',
#  'supermarkets',
#  '.ipynb_checkpoints']

# %%
import pandas

# %%
df3=pandas.read_csv("supermarkets/supermarkets.csv")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_json_file=pandas.read_json("supermarkets/supermarkets.json")
df_json_file
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
load_excel = pandas.read_excel("supermarkets/supermarkets.xlsx", sheet_name=0)
load_excel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
load_txt=pandas.read_csv("supermarkets/supermarkets-commas.txt")
load_txt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
load_txt_sep=pandas.read_csv("supermarkets/supermarkets-semi-colons.txt", sep=";")
load_txt_sep
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
no_header = pandas.read_csv("supermarkets/supermarkets-commas.txt", header=None)
no_header
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
no_header2=pandas.read_csv("supermarkets/data.txt", header=None)
no_header2
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
no_header2.columns = ["ID", "Address", "City", "State", "Country", "Name", "EmployeeNumbers"]
no_header2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    EmployeeNumbers
# 0                8
# 1               15
# 2               25
# 3               10
# 4               12
# 5               20

# %%
no_header2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     EmployeeNumbers
# ID
# 1                 8
# 2                15
# 3                25
# 4                10
# 5                12
# 6                20

# %%
no_header2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    EmployeeNumbers
# 0                8
# 1               15
# 2               25
# 3               10
# 4               12
# 5               20

# %%
set_index_no_header = no_header2.set_index("ID")
set_index_no_header
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     EmployeeNumbers
# ID
# 1                 8
# 2                15
# 3                25
# 4                10
# 5                12
# 6                20

# %%
set_index_no_header.loc["735 Dolores St":"332 Hill St", "Country":"Name"]
# Out:
# Empty DataFrame
# Columns: [Country, Name]
# Index: []

# %%
abc=pandas.read_json("supermarkets/supermarkets.json")
abc=abc.set_index("Address")
abc
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
abc.loc["735 Dolores St":"332 Hill St", "Country":"Name"]
# Out:
#                Country         Name
# Address
# 735 Dolores St     USA  Bready Shop
# 332 Hill St        USA  Super River

# %%
abc.loc["332 Hill St", "Country"]
# Out:
# 'USA'

# %%
abc.loc[:, "State":"Country"]
# Out:
#                             State Country
# Address
# 3666 21st St             CA 94114     USA
# 735 Dolores St           CA 94119     USA
# 332 Hill St      California 94114     USA
# 3995 23rd St             CA 94114     USA
# 1056 Sanchez St        California     USA
# 551 Alvarado St          CA 94114     USA

# %%
abc
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
abc.iloc[1:4,1:3]
# Out:
#                          City             State
# Address
# 735 Dolores St  San Francisco          CA 94119
# 332 Hill St     San Francisco  California 94114
# 3995 23rd St    San Francisco          CA 94114

# %%
abc.iloc? # help

# %%
abc.iloc[:,1:3]
# Out:
#                           City             State
# Address
# 3666 21st St     San Francisco          CA 94114
# 735 Dolores St   San Francisco          CA 94119
# 332 Hill St      San Francisco  California 94114
# 3995 23rd St     San Francisco          CA 94114
# 1056 Sanchez St  San Francisco        California
# 551 Alvarado St  San Francisco          CA 94114

# %%
abc.drop("City",1)
# Out:
#                  ID             State Country         Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA      Madeira          8
# 735 Dolores St    2          CA 94119     USA  Bready Shop         15
# 332 Hill St       3  California 94114     USA  Super River         25
# 3995 23rd St      4          CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5        California     USA      Sanchez         12
# 551 Alvarado St   6          CA 94114     USA   Richvalley         20

# %%
abc.drop("State",1)
# Out:
#                  ID           City Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco     USA      Madeira          8
# 735 Dolores St    2  San Francisco     USA  Bready Shop         15
# 332 Hill St       3  San Francisco     USA  Super River         25
# 3995 23rd St      4  San Francisco     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco     USA   Richvalley         20

# %%
abc.drop(abc.index[:3],0) # delete 3 rows
# Out:
#                  ID           City       State Country        Name  Employees
# Address
# 3995 23rd St      4  San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
abc.drop(abc.columns[:3],1)
# Out:
#                 Country         Name  Employees
# Address
# 3666 21st St        USA      Madeira          8
# 735 Dolores St      USA  Bready Shop         15
# 332 Hill St         USA  Super River         25
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12
# 551 Alvarado St     USA   Richvalley         20

# %%
abc["Continent"]=abc.shape[0]*["North America"]

# %%
abc
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
abc.shape # get the row, column of the data
# Out:
# (6, 7)

# %%
abc.shape[0] # get row number of data
# Out:
# 6

# %%
abc.shape?

# %%
abc_t = abc.T

# %%
abc_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# ID                     1              2                 3              4
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# Employees              8             15                25             10
# Continent  North America  North America     North America  North America
#
# Address   1056 Sanchez St 551 Alvarado St
# ID                      5               6
# City        San Francisco   San Francisco
# State          California        CA 94114
# Country               USA             USA
# Name              Sanchez      Richvalley
# Employees              12              20
# Continent   North America   North America

# %%
abc_t["My Address"]=[10,"Bayrmaly", "Mary", "TM","tapjangul",100, "Eaurope"]

# %%
abc_t.T
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
# My Address       10       Bayrmaly              Mary      TM    tapjangul
#
#                 Employees      Continent
# Address
# 3666 21st St            8  North America
# 735 Dolores St         15  North America
# 332 Hill St            25  North America
# 3995 23rd St           10  North America
# 1056 Sanchez St        12  North America
# 551 Alvarado St        20  North America
# My Address            100        Eaurope
